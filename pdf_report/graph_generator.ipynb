# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file = r'C:\Users\vladi\Desktop\gpu_prace\data.xlsx'

# %%
df = pd.read_excel(file)
df['CPU_METHOD'] = df['CPU_METHOD'].astype(bool)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(df)
# Out:
#    TEST_SET  FPS_8bit  FPS_32bit  FPS_8bit_REAL  FPS_32bit_REAL  \
# 0        t1      10.0       10.0           10.0            10.0
# 1        t1      20.0       20.0           20.0            20.0
# 2        t1    2205.0     1715.0         1768.0          1452.0
# 3        t1    2200.0     1705.0         1770.0          1450.0
# 4        t1    2199.0     1650.0         1720.0          1310.0
# 5        t2       5.5        5.5            5.5             5.5
# 6        t2      10.0       10.0           10.0            10.0
# 7        t2    1385.0     1150.0         1100.0           970.0
# 8        t2    1379.0     1152.0         1101.0           971.0
# 9        t2    1380.0     1355.0         1095.0          1120.0
# 10       t3       3.0        3.0            3.0             3.0
# 11       t3       6.0        6.0            6.0             6.0
# 12       t3    1110.0      962.0          950.0           845.0
# 13       t3    1095.0      965.0          945.0           852.0
# 14       t3    1101.0     1160.0          950.0          1025.0
# 15       t4       0.0        0.0            0.0             0.0
# 16       t4       1.0        1.0            1.0             1.0
# 17       t4     136.0      127.0          125.0           117.0
# 18       t4     137.0      126.0          122.0           116.0
# 19       t4     135.0      231.0          128.0           170.0
# 20       t5     100.0       90.0          100.0            88.0
# 21       t5     101.0       92.0          101.0            88.0
# 22       t5      99.0      140.0           98.0           120.0
# 23       t6      85.0       72.0           83.0            70.0
# 24       t6      83.0       71.0           83.0            72.0
# 25       t6      85.0      130.0           83.0           118.0
# 26       t7      60.0       55.0           49.0            45.0
# 27       t7      30.0       56.0           49.0            46.0
# 28       t7      60.0      100.0           49.0           100.0
# 29       t8      38.0       35.0           32.0            30.0
# 30       t8      38.0       35.0           31.0            31.0
# 31       t8      39.0       65.0           32.0            66.0
# 32       t9      20.0       18.0           20.0            17.0
# 33       t9      19.0       18.0           20.0            17.0
# 34       t9      20.0       30.0           19.0            29.0
# 35       t7      60.0       50.0            NaN             NaN
# 36       t7       NaN      100.0            NaN             NaN
# 37       t8      37.0       35.0            NaN             NaN
# 38       t8       NaN       65.0            NaN             NaN
# 39       t9      20.0       17.0            NaN             NaN
# 40       t9       NaN       26.0            NaN             NaN
# 41       t7      60.0       55.0            NaN             NaN
# 42       t7       NaN      100.0            NaN             NaN
# 43       t8      36.0       33.0            NaN             NaN
# 44       t8       NaN       70.0            NaN             NaN
# 45       t9      20.0       18.0            NaN             NaN
# 46       t9       NaN       30.0            NaN             NaN
# 47       t1      11.0       11.0           11.0            11.0
# 48       t1      22.0       22.0           22.0            22.0
# 49       t1    2100.0     1500.0         1500.0          1200.0
# 50       t1       NaN     1400.0            NaN          1309.0
# 51       t2       5.7        5.7            5.7             5.7
# 52       t2      11.0       11.0           11.0            11.0
# 53       t2    1800.0     1300.0         1500.0          1100.0
# 54       t2       NaN     1300.0            NaN          1200.0
# 55       t3       3.8        3.8            3.8             3.8
# 56       t3       7.5        7.5            7.5             7.5
# 57       t3    1600.0     1300.0         1500.0          1100.0
# 58       t3       NaN     1200.0            NaN          1100.0
# 59       t4     150.0      145.0          135.0           125.0
# 60       t4       NaN      250.0            NaN           235.0
# 61       t5     120.0      110.0          102.0            99.0
# 62       t5       NaN      205.0            NaN           192.0
# 63       t6     101.0       95.0           95.0            94.0
# 64       t6       NaN      170.0            NaN           167.0
# 65       t7      70.0       72.0           60.0            57.0
# 66       t7       NaN      160.0            NaN           165.0
# 67       t8      78.0       45.0           53.0            40.0
# 68       t8       NaN       92.0            NaN            91.0
# 69       t9      40.0       26.0           30.0            23.0
# 70       t9       NaN       40.0            NaN            40.0
#
#                    IDW_METHOD  CPU_UT_8bit  GPU_UT_8bit  CPU_UT_32bit  \
# 0                   CPU_BASIC         18.0          1.0          18.0
# 1                CPU_THREADED         30.0          5.0          30.0
# 2           GPU_GLOBAL_MEMORY         20.0         82.0          20.0
# 3          GPU_TEXTURE_MEMORY         20.0         82.0          20.0
# 4   GPU_TEXTURE_MEMORY_OPENGL         20.0         60.0          20.0
# 5                   CPU_BASIC         16.0          1.0          16.0
# 6                CPU_THREADED         30.0          2.0          30.0
# 7           GPU_GLOBAL_MEMORY         20.0         82.0          20.0
# 8          GPU_TEXTURE_MEMORY         21.0         85.0          19.0
# 9   GPU_TEXTURE_MEMORY_OPENGL         20.0         60.0          20.0
# 10                  CPU_BASIC         16.0          0.0          16.0
# 11               CPU_THREADED         30.0          0.0          30.0
# 12          GPU_GLOBAL_MEMORY         20.0         99.0          20.0
# 13         GPU_TEXTURE_MEMORY         19.0         98.0          20.0
# 14  GPU_TEXTURE_MEMORY_OPENGL         20.0         80.0          20.0
# 15                  CPU_BASIC          NaN          NaN           NaN
# 16               CPU_THREADED          NaN          NaN           NaN
# 17          GPU_GLOBAL_MEMORY         20.0        100.0          20.0
# 18         GPU_TEXTURE_MEMORY         19.0        100.0          21.0
# 19  GPU_TEXTURE_MEMORY_OPENGL         20.0         21.0          20.0
# 20          GPU_GLOBAL_MEMORY         20.0         93.0          20.0
# 21         GPU_TEXTURE_MEMORY         21.0         92.0          21.0
# 22  GPU_TEXTURE_MEMORY_OPENGL         20.0         70.0          20.0
# 23          GPU_GLOBAL_MEMORY         19.0         85.0          21.0
# 24         GPU_TEXTURE_MEMORY         20.0         86.0          20.0
# 25  GPU_TEXTURE_MEMORY_OPENGL         20.0         65.0          21.0
# 26          GPU_GLOBAL_MEMORY         22.0        100.0          25.0
# 27         GPU_TEXTURE_MEMORY         20.0        100.0          20.0
# 28  GPU_TEXTURE_MEMORY_OPENGL         19.0        100.0          22.0
# 29          GPU_GLOBAL_MEMORY         20.0        100.0          18.0
# 30         GPU_TEXTURE_MEMORY         21.0        100.0          20.0
# 31  GPU_TEXTURE_MEMORY_OPENGL         18.0        100.0          17.0
# 32          GPU_GLOBAL_MEMORY         20.0         72.0          20.0
# 33         GPU_TEXTURE_MEMORY         21.0         71.0          20.0
# 34  GPU_TEXTURE_MEMORY_OPENGL         20.0         68.0          19.0
# 35          GPU_GLOBAL_MEMORY          NaN        100.0           NaN
# 36  GPU_TEXTURE_MEMORY_OPENGL          NaN         90.0           NaN
# 37          GPU_GLOBAL_MEMORY          NaN        100.0           NaN
# 38  GPU_TEXTURE_MEMORY_OPENGL          NaN         95.0           NaN
# 39          GPU_GLOBAL_MEMORY          NaN         78.0           NaN
# 40  GPU_TEXTURE_MEMORY_OPENGL          NaN         67.0           NaN
# 41          GPU_GLOBAL_MEMORY          NaN        100.0           NaN
# 42  GPU_TEXTURE_MEMORY_OPENGL          NaN        100.0           NaN
# 43          GPU_GLOBAL_MEMORY          NaN        100.0           NaN
# 44  GPU_TEXTURE_MEMORY_OPENGL          NaN         96.0           NaN
# 45          GPU_GLOBAL_MEMORY          NaN         65.0           NaN
# 46  GPU_TEXTURE_MEMORY_OPENGL          NaN         69.0           NaN
# 47                  CPU_BASIC          NaN          NaN           NaN
# 48               CPU_THREADED          NaN          NaN           NaN
# 49          GPU_GLOBAL_MEMORY          NaN          NaN           NaN
# 50  GPU_TEXTURE_MEMORY_OPENGL          NaN          NaN           NaN
# 51                  CPU_BASIC          NaN          NaN           NaN
# 52               CPU_THREADED          NaN          NaN           NaN
# 53          GPU_GLOBAL_MEMORY          NaN          NaN           NaN
# 54  GPU_TEXTURE_MEMORY_OPENGL          NaN          NaN           NaN
# 55                  CPU_BASIC          NaN          NaN           NaN
# 56               CPU_THREADED          NaN          NaN           NaN
# 57          GPU_GLOBAL_MEMORY          NaN          NaN           NaN
# 58  GPU_TEXTURE_MEMORY_OPENGL          NaN          NaN           NaN
# 59          GPU_GLOBAL_MEMORY          NaN          NaN           NaN
# 60  GPU_TEXTURE_MEMORY_OPENGL          NaN          NaN           NaN
# 61          GPU_GLOBAL_MEMORY          NaN          NaN           NaN
# 62  GPU_TEXTURE_MEMORY_OPENGL          NaN          NaN           NaN
# 63          GPU_GLOBAL_MEMORY          NaN          NaN           NaN
# 64  GPU_TEXTURE_MEMORY_OPENGL          NaN          NaN           NaN
# 65          GPU_GLOBAL_MEMORY          NaN          NaN           NaN
# 66  GPU_TEXTURE_MEMORY_OPENGL          NaN          NaN           NaN
# 67          GPU_GLOBAL_MEMORY          NaN          NaN           NaN
# 68  GPU_TEXTURE_MEMORY_OPENGL          NaN          NaN           NaN
# 69          GPU_GLOBAL_MEMORY          NaN          NaN           NaN
# 70  GPU_TEXTURE_MEMORY_OPENGL          NaN          NaN           NaN
#
#     GPU_UT_32bit CHUNK_SIZE  IMG_SIZE  CPU_METHOD TEST_COMPUTER TEST_SESSION
# 0            1.0        NaN       256        True           UNO         BASE
# 1            5.0        NaN       256        True           UNO         BASE
# 2           82.0      16x16       256       False           UNO         BASE
# 3           83.0      16x16       256       False           UNO         BASE
# 4           20.0      16x16       256       False           UNO         BASE
# 5            1.0        NaN       256        True           UNO         BASE
# 6            2.0        NaN       256        True           UNO         BASE
# 7           82.0      16x16       256       False           UNO         BASE
# 8           82.0      16x16       256       False           UNO         BASE
# 9           26.0      16x16       256       False           UNO         BASE
# 10           0.0        NaN       256        True           UNO         BASE
# 11           0.0        NaN       256        True           UNO         BASE
# 12          99.0      16x16       256       False           UNO         BASE
# 13         100.0      16x16       256       False           UNO         BASE
# 14          73.0      16x16       256       False           UNO         BASE
# 15           NaN        NaN       768        True           UNO         BASE
# 16           NaN        NaN       768        True           UNO         BASE
# 17         100.0      16x16       768       False           UNO         BASE
# 18         100.0      16x16       768       False           UNO         BASE
# 19          41.0      16x16       768       False           UNO         BASE
# 20          94.0      16x16       768       False           UNO         BASE
# 21          93.0      16x16       768       False           UNO         BASE
# 22          29.0      16x16       768       False           UNO         BASE
# 23          85.0      16x16       768       False           UNO         BASE
# 24          85.0      16x16       768       False           UNO         BASE
# 25          24.0      16x16       768       False           UNO         BASE
# 26         100.0      16x16      1920       False           UNO         BASE
# 27         100.0      16x16      1920       False           UNO         BASE
# 28          25.0      16x16      1920       False           UNO         BASE
# 29         100.0      16x16      1920       False           UNO         BASE
# 30         100.0      16x16      1920       False           UNO         BASE
# 31          18.0      16x16      1920       False           UNO         BASE
# 32          78.0      16x16      1920       False           UNO         BASE
# 33          76.0      16x16      1920       False           UNO         BASE
# 34          11.0      16x16      1920       False           UNO         BASE
# 35         100.0      32x32      1920       False           UNO   CHUNK_SIZE
# 36          20.0      32x32      1920       False           UNO   CHUNK_SIZE
# 37         100.0      32x32      1920       False           UNO   CHUNK_SIZE
# 38          20.0      32x32      1920       False           UNO   CHUNK_SIZE
# 39          78.0      32x32      1920       False           UNO   CHUNK_SIZE
# 40          12.0      32x32      1920       False           UNO   CHUNK_SIZE
# 41         100.0        8x8      1920       False           UNO   CHUNK_SIZE
# 42          25.0        8x8      1920       False           UNO   CHUNK_SIZE
# 43         100.0        8x8      1920       False           UNO   CHUNK_SIZE
# 44          20.0        8x8      1920       False           UNO   CHUNK_SIZE
# 45          79.0        8x8      1920       False           UNO   CHUNK_SIZE
# 46          12.0        8x8      1920       False           UNO   CHUNK_SIZE
# 47           NaN        NaN       256        True           DUO      DIFF_PC
# 48           NaN        NaN       256        True           DUO      DIFF_PC
# 49           NaN      16x16       256       False           DUO      DIFF_PC
# 50           NaN      16x16       256       False           DUO      DIFF_PC
# 51           NaN        NaN       256        True           DUO      DIFF_PC
# 52           NaN        NaN       256        True           DUO      DIFF_PC
# 53           NaN      16x16       256       False           DUO      DIFF_PC
# 54           NaN      16x16       256       False           DUO      DIFF_PC
# 55           NaN        NaN       256        True           DUO      DIFF_PC
# 56           NaN        NaN       256        True           DUO      DIFF_PC
# 57           NaN      16x16       256       False           DUO      DIFF_PC
# 58           NaN      16x16       256       False           DUO      DIFF_PC
# 59           NaN      16x16       768       False           DUO      DIFF_PC
# 60           NaN      16x16       768       False           DUO      DIFF_PC
# 61           NaN      16x16       768       False           DUO      DIFF_PC
# 62           NaN      16x16       768       False           DUO      DIFF_PC
# 63           NaN      16x16       768       False           DUO      DIFF_PC
# 64           NaN      16x16       768       False           DUO      DIFF_PC
# 65           NaN      16x16      1920       False           DUO      DIFF_PC
# 66           NaN      16x16      1920       False           DUO      DIFF_PC
# 67           NaN      16x16      1920       False           DUO      DIFF_PC
# 68           NaN      16x16      1920       False           DUO      DIFF_PC
# 69           NaN      16x16      1920       False           DUO      DIFF_PC
# 70           NaN      16x16      1920       False           DUO      DIFF_PC

# %%
# add 8 bit and 32 bit version ...

#gain ?in percent ...??

#compare gpu ut / cpu ut
#compare fps 8bit vs 32bit
# compare real vs method fps

#i am not using alpha ....

# %%
df_plot = df[(df['TEST_SESSION'] == 'BASE') & (~df['CPU_METHOD'])]

plt.figure(figsize=(10, 5))
sns.barplot(data=df_plot, y='FPS_8bit', x='TEST_SET', hue='IDW_METHOD')
plt.title('Comparison of FPS by different test set and idw method')
# Out:
# Text(0.5, 1.0, 'Comparison of FPS by different test set and idw method')

# %%
df_plot = df[(df['TEST_SESSION'] == 'BASE') & (df['IMG_SIZE'] > 256) & (~df['CPU_METHOD'])]

plt.figure(figsize=(10, 5))
sns.barplot(data=df_plot, y='FPS_8bit', x='TEST_SET', hue='IDW_METHOD')
plt.title('Comparison of FPS by different test set and idw method - zoom')
# Out:
# Text(0.5, 1.0, 'Comparison of FPS by different test set and idw method - zoom')

# %%
df_plot = df[(df['TEST_SESSION'] == 'BASE')]

plt.figure(figsize=(10, 5))
# sns.barplot(data=df_plot, y='CPU_UT_32bit', x='TEST_SET', hue='IDW_METHOD')
sns.barplot(data=df_plot, y='GPU_UT_32bit', x='TEST_SET', hue='IDW_METHOD')
plt.title('Comparison of GPU utilization by different test set and idw method')
# Out:
# Text(0.5, 1.0, 'Comparison of GPU utilization by different test set and idw method')

# %%
#different chunk size
df_plot = df[(~df['CPU_METHOD']) & (df['TEST_COMPUTER'] == 'UNO') & (df['IMG_SIZE'] == 1920) & (df['IDW_METHOD'] != 'GPU_TEXTURE_MEMORY')]
sns.barplot(data=df_plot, y='FPS_32bit', x='TEST_SET', hue='CHUNK_SIZE')

g = sns.catplot(x="TEST_SET", y="FPS_32bit", hue="CHUNK_SIZE", col="IDW_METHOD",data=df_plot, kind="bar")
plt.subplots_adjust(top=0.9)
g.fig.suptitle('Comparison of FPS based on different thread block size')

g = sns.catplot(x="TEST_SET", y="GPU_UT_32bit", hue="CHUNK_SIZE", col="IDW_METHOD",data=df_plot, kind="bar")
plt.subplots_adjust(top=0.9)
g.fig.suptitle('Comparison of GPU utliziation based on different thread block size')
# Out:
# Text(0.5, 0.98, 'Comparison of GPU utliziation based on different thread block size')

# %%
df_plot = df[(~df['CPU_METHOD']) & (df['TEST_COMPUTER'] == 'UNO') & (df['IMG_SIZE'] == 1920) & (df['IDW_METHOD'] != 'GPU_TEXTURE_MEMORY')]
sns.barplot(data=df_plot, y='FPS_32bit', x='TEST_SET', hue='CHUNK_SIZE')
# Out:
# <AxesSubplot:xlabel='TEST_SET', ylabel='FPS_32bit'>

# %%
#different hardware
df_plot = df[(df['TEST_SESSION'] != 'CHUNK_SIZE') & (df['IMG_SIZE'] != 256) & ((df['IDW_METHOD'] == 'GPU_GLOBAL_MEMORY') | (df['IDW_METHOD'] == 'GPU_TEXTURE_MEMORY_OPENGL'))]
g = sns.catplot(x="TEST_SET", y="FPS_32bit", col="IDW_METHOD", hue="GPU_MODEL",data=df_plot, kind="bar")

plt.subplots_adjust(top=0.87)
g.fig.suptitle('Comparison of FPS on two different GPUs',size=16)
# Out:
# Text(0.5, 0.98, 'Comparison of FPS on two different GPUs')

# %%
df_plot
# Out:
#    TEST_SET  FPS_8bit  FPS_32bit  FPS_8bit_REAL  FPS_32bit_REAL  \
# 17       t4     136.0      127.0          125.0           117.0
# 19       t4     135.0      231.0          128.0           170.0
# 20       t5     100.0       90.0          100.0            88.0
# 22       t5      99.0      140.0           98.0           120.0
# 23       t6      85.0       72.0           83.0            70.0
# 25       t6      85.0      130.0           83.0           118.0
# 26       t7      60.0       55.0           49.0            45.0
# 28       t7      60.0      100.0           49.0           100.0
# 29       t8      38.0       35.0           32.0            30.0
# 31       t8      39.0       65.0           32.0            66.0
# 32       t9      20.0       18.0           20.0            17.0
# 34       t9      20.0       30.0           19.0            29.0
# 59       t4     150.0      145.0          135.0           125.0
# 60       t4       NaN      250.0            NaN           235.0
# 61       t5     120.0      110.0          102.0            99.0
# 62       t5       NaN      205.0            NaN           192.0
# 63       t6     101.0       95.0           95.0            94.0
# 64       t6       NaN      170.0            NaN           167.0
# 65       t7      70.0       72.0           60.0            57.0
# 66       t7       NaN      160.0            NaN           165.0
# 67       t8      78.0       45.0           53.0            40.0
# 68       t8       NaN       92.0            NaN            91.0
# 69       t9      40.0       26.0           30.0            23.0
# 70       t9       NaN       40.0            NaN            40.0
#
#                    IDW_METHOD  CPU_UT_8bit  GPU_UT_8bit  CPU_UT_32bit  \
# 17          GPU_GLOBAL_MEMORY         20.0        100.0          20.0
# 19  GPU_TEXTURE_MEMORY_OPENGL         20.0         21.0          20.0
# 20          GPU_GLOBAL_MEMORY         20.0         93.0          20.0
# 22  GPU_TEXTURE_MEMORY_OPENGL         20.0         70.0          20.0
# 23          GPU_GLOBAL_MEMORY         19.0         85.0          21.0
# 25  GPU_TEXTURE_MEMORY_OPENGL         20.0         65.0          21.0
# 26          GPU_GLOBAL_MEMORY         22.0        100.0          25.0
# 28  GPU_TEXTURE_MEMORY_OPENGL         19.0        100.0          22.0
# 29          GPU_GLOBAL_MEMORY         20.0        100.0          18.0
# 31  GPU_TEXTURE_MEMORY_OPENGL         18.0        100.0          17.0
# 32          GPU_GLOBAL_MEMORY         20.0         72.0          20.0
# 34  GPU_TEXTURE_MEMORY_OPENGL         20.0         68.0          19.0
# 59          GPU_GLOBAL_MEMORY          NaN          NaN           NaN
# 60  GPU_TEXTURE_MEMORY_OPENGL          NaN          NaN           NaN
# 61          GPU_GLOBAL_MEMORY          NaN          NaN           NaN
# 62  GPU_TEXTURE_MEMORY_OPENGL          NaN          NaN           NaN
# 63          GPU_GLOBAL_MEMORY          NaN          NaN           NaN
# 64  GPU_TEXTURE_MEMORY_OPENGL          NaN          NaN           NaN
# 65          GPU_GLOBAL_MEMORY          NaN          NaN           NaN
# 66  GPU_TEXTURE_MEMORY_OPENGL          NaN          NaN           NaN
# 67          GPU_GLOBAL_MEMORY          NaN          NaN           NaN
# 68  GPU_TEXTURE_MEMORY_OPENGL          NaN          NaN           NaN
# 69          GPU_GLOBAL_MEMORY          NaN          NaN           NaN
# 70  GPU_TEXTURE_MEMORY_OPENGL          NaN          NaN           NaN
#
#     GPU_UT_32bit CHUNK_SIZE  IMG_SIZE  CPU_METHOD GPU_MODEL TEST_SESSION
# 17         100.0      16x16       768       False   1080 Ti         BASE
# 19          41.0      16x16       768       False   1080 Ti         BASE
# 20          94.0      16x16       768       False   1080 Ti         BASE
# 22          29.0      16x16       768       False   1080 Ti         BASE
# 23          85.0      16x16       768       False   1080 Ti         BASE
# 25          24.0      16x16       768       False   1080 Ti         BASE
# 26         100.0      16x16      1920       False   1080 Ti         BASE
# 28          25.0      16x16      1920       False   1080 Ti         BASE
# 29         100.0      16x16      1920       False   1080 Ti         BASE
# 31          18.0      16x16      1920       False   1080 Ti         BASE
# 32          78.0      16x16      1920       False   1080 Ti         BASE
# 34          11.0      16x16      1920       False   1080 Ti         BASE
# 59           NaN      16x16       768       False   2080 Ti      DIFF_PC
# 60           NaN      16x16       768       False   2080 Ti      DIFF_PC
# 61           NaN      16x16       768       False   2080 Ti      DIFF_PC
# 62           NaN      16x16       768       False   2080 Ti      DIFF_PC
# 63           NaN      16x16       768       False   2080 Ti      DIFF_PC
# 64           NaN      16x16       768       False   2080 Ti      DIFF_PC
# 65           NaN      16x16      1920       False   2080 Ti      DIFF_PC
# 66           NaN      16x16      1920       False   2080 Ti      DIFF_PC
# 67           NaN      16x16      1920       False   2080 Ti      DIFF_PC
# 68           NaN      16x16      1920       False   2080 Ti      DIFF_PC
# 69           NaN      16x16      1920       False   2080 Ti      DIFF_PC
# 70           NaN      16x16      1920       False   2080 Ti      DIFF_PC

# %%
145 / 127
# Out:
# 1.141732283464567
